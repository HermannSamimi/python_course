# %% [markdown]
# # Task 1:
#
# ### please create a json document using these data:
#
# students:
#
# student ID = 1002110
# name -> first name = henry, last name = jacob
# contact -> email = hj@gmail.com, phone = (001)123456789
# address -> country = USA, city= New york
# Grade = A+
#
# student ID = 1002112
# name -> first name = oliver, last name = stanford
# phone = (001)123456710
# city= New york
# grade = C-
#
# student ID = 1002187
# name -> first name = alex, last name = nova
# contact -> email = an@gmail.com, phone = (001)123465
# country = USA
# grade = b
#
# student ID = 1002144
# name -> first name = jason, last name = ford
# contact -> email = jf@gmail.com, phone = (001)123456664
# address -> country = USA, city= New york
# grade = b-

# %%
my_data = {
    "student ID" : "1002110",
    "first name" : "henry",
    "last name" : "jacob",
    "email" : "hj@gmail.com",
    "phone number" : "(001)123456789",
    "country" : "USA",
    "city" : "New York",
    "grade" : "A+"
}

# %% [markdown]
# # Task 2:
#
# ```
# data = {
#     "employees": [
#         {
#             "employee_id": "E001",
#             "name": {"first": "Alice", "last": "Johnson"},
#             "contact": {"email": "alice.johnson@example.com", "phone": "+1-555-1234"},
#             "address": {"country": "USA", "state": "California", "city": "San Francisco"},
#             "skills": {"programming": ["Python", "JavaScript"], "tools": ["Git", "Docker"]}
#         },
#         {
#             "employee_id": "E002",
#             "name": {"first": "Bob", "last": "Lee"},
#             "contact": {"email": "bob.lee@example.com", "phone": "+1-555-5678"},
#             "address": {"country": "Canada", "province": "Ontario", "city": "Toronto"},
#             "skills": {"programming": ["Java", "Go"], "tools": ["Kubernetes", "Jenkins"]}
#         },
#         {
#             "employee_id": "E003",
#             "name": {"first": "Clara", "last": "Nguyen"},
#             "contact": {"email": "clara.nguyen@example.com", "phone": "+1-555-9012"},
#             "address": {"country": "UK", "city": "London"},
#             "skills": {"programming": ["C++", "Rust"], "tools": ["VS Code", "Ansible"]}
#         }
#     ]
# }
# ```
#
# ## 🔹 Question 1: Get Bob Lee’s email address
#
# ## 🔹 Question 2: Print all employee full names
#
# ## 🔹 Question 3: Find all employees with Python skill
#
# ## 🔹 Question 4: Print cities of all employees
#
# ## 🔹 Question 5: Return emails of employees who use Jenkins

# %%
data = {
    "employees": [
        {
            "employee_id": "E001",
            "name": {"first": "Alice", "last": "Johnson"},
            "contact": {"email": "alice.johnson@example.com", "phone": "+1-555-1234"},
            "address": {"country": "USA", "state": "California", "city": "San Francisco"},
            "skills": {"programming": ["Python", "JavaScript"], "tools": ["Git", "Docker"]}
        },
        {
            "employee_id": "E002",
            "name": {"first": "Bob", "last": "Lee"},
            "contact": {"email": "bob.lee@example.com", "phone": "+1-555-5678"},
            "address": {"country": "Canada", "province": "Ontario", "city": "Toronto"},
            "skills": {"programming": ["Java", "Go"], "tools": ["Kubernetes", "Jenkins"]}
        },
        {
            "employee_id": "E003",
            "name": {"first": "Clara", "last": "Nguyen"},
            "contact": {"email": "clara.nguyen@example.com", "phone": "+1-555-9012"},
            "address": {"country": "UK", "city": "London"},
            "skills": {"programming": ["C++", "Rust"], "tools": ["VS Code", "Ansible"]}
        }
    ]
}
## 🔹 Question 1: Get Bob Lee’s email address
bob_email = data["employees"][1]["contact"]["email"]
print(f"Bob Lee's email address is: {bob_email}")



## 🔹 Question 2: Print all employee full names
for i in data["employees"]:
    full_name = f"{i['name']['first']} {i['name']['last']}"
    print(full_name)



## 🔹 Question 3: Find all employees with Python skill

python_employees = [emp for emp in data["employees"] if "Python" in emp["skills"]["programming"]]
## 🔹 Question 4: Print cities of all employees

## 🔹 Question 5: Return emails of employees who use Jenkins
# Out:
# Bob Lee's email address is: bob.lee@example.com
# Alice Johnson
# Bob Lee
# Clara Nguyen

# %% [markdown]
# # Task 3:<br>
# You are given the following Python variable containing employee data in JSON format:
#
# ```
# data = {"employees":[{"employee_id":"E001","name":{"first":"Alice","last":"Johnson"},"contact":{"email":"alice.johnson@example.com","phone":"+1-555-1234"},"address":{"country":"USA","state":"California","city":"San Francisco"},"skills":{"programming":["Python","JavaScript"],"tools":["Git","Docker"]}},{"employee_id":"E002","name":{"first":"Bob","last":"Lee"},"contact":{"email":"bob.lee@example.com","phone":"+1-555-5678"},"address":{"country":"Canada","province":"Ontario","city":"Toronto"},"skills":{"programming":["Java","Go"],"tools":["Kubernetes","Jenkins"]}},{"employee_id":"E003","name":{"first":"Clara","last":"Nguyen"},"contact":{"email":"clara.nguyen@example.com","phone":"+1-555-9012"},"address":{"country":"UK","city":"London"},"skills":{"programming":["C++","Rust"],"tools":["VS Code","Ansible"]}}]}
# ```
#
# Pretty-print the entire JSON using `json.dumps()` with an indentation of 4 spaces.

# %% [markdown]
# # Task 4:
#
# ```
# data_centers = {
#     'Frankfurt':
#     {
#         "name": "Frankfurt",
#         "country": "Germany",
#         "capacity": 1000,
#         "available": True
#     },
#     'amsterdam':
#     {
#         "name": "Amsterdam",
#         "country": "Netherlands",
#         "capacity": 800,
#         "available": False
#     },
#     'london':
#     {
#         "name": "London",
#         "country": "UK",
#         "capacity": 1200,
#         "available": True
#     },
#     'paris':
#     {
#         "name": "Paris",
#         "country": "France",
#         "capacity": 900,
#         "available": True
#     },
#     'madrid':
#     {
#         "name": "Madrid",
#         "country": "Spain",
#         "capacity": 700,
#         "available": False
#     },
#     'milan':
#     {
#         "name": "Milan",
#         "country": "Italy",
#         "capacity": 600,
#         "available": True
#     },
#     'berlin':
#     {
#         "name": "Berlin",
#         "country": "Germany",
#         "capacity": 1100,
#         "available": True
#     },
# }
# ```
#
# 1. Print the names of all data centers located in Germany.
# 2. Print the country and capacity of each data center that has more than 900 capacity.
# 3. Print only the names of available data centers.
# 4. Print all data centers in this format: `Location: London, Country: UK, Capacity: 1200, Available: Yes`
# 5. Count how many data centers are available and how many are not.

# %% [markdown]
# # Task 5
#
# 1. create a txt file
# 2. puth this context in it:
#     ```
#     mode is an optional string that specifies the mode in which the file is opened. It defaults to 'r' which means open for reading in text mode. Other common values are 'w' for writing (truncating the file if it already exists), 'x' for exclusive creation, and 'a' for appending (which on some Unix systems, means that all writes append to the end of the file regardless of the current seek position). In text mode, if encoding is not specified the encoding used is platform-dependent: locale.getencoding() is called to get the current locale encoding. (For reading and writing raw bytes use binary mode and leave encoding unspecified.) The available modes are:
#     ```
# 3. Open the file in read mode.
# 4. Read the contents and split it into lines.
# 5. close it.

# %% [markdown]
# # Task 6
# ### Write a Python script that:
# 1.	Asks the user to input:
# 	•	Their full name
# 	•	A username
# 	•	A password
# 2.	Saves this information to a file called credential.txt in the following format:
#     `full_name,username,password`
# 3. Use file.write() to store the information, and make sure the file is properly closed after writing.
#
#
# Example output: Enter your full name:<br>
# ```
# Alice Brown
# Enter your username: alice.b
# Enter your password: secret123
# ```
# Expected File Content (credential.txt):
# `Alice Brown,alice.b,secret123`

# %% [markdown]
# # Task 7
# You’re building a simple app for people to submit short book reviews. Every time a user submits a review, it should be added to a log file. After each submission, all past reviews should be shown.
# Your script should do the following:<br>
# 1.	Ask the user to enter:
# 	•	Their full name
# 	•	The title of the book they are reviewing
# 	•	A short review (1 sentence)
# 2.	Append this data to a file in the following format:
#     `Reviewer: Alice Brown | Book: 1984 | Review: Powerful and haunting.`
# 3. save data to a file
# 4.	After saving, read the entire file and print all reviews.
#
#
#  Example Output:
#  ```
# Enter your full name: Alice Brown
# Enter the book title: 1984
# Enter your review: Powerful and haunting.
#
# ✅ Review saved!
#
# 📚 All Reviews:
# Reviewer: Alice Brown | Book: 1984 | Review: Powerful and haunting.
# Reviewer: John Smith | Book: Dune | Review: Epic world-building.
# ```
